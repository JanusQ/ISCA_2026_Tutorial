# %% [markdown]
# # 3.1 Hardware Interface
#
# This notebook describes the hardware-facing interface used by the tutorial. The complete Vivado project is intentionally not included; only the interface contract is kept in `artery/hw/interface`.

# %%
from pathlib import Path
base = Path('../../hw/interface')
for name in ['artery_feedback_interface.v', 'udp_packet_format.md', 'feedback_datapath.md']:
    p = base / name
    print(p, 'exists =', p.exists())

# %% [markdown]
# ## Interface Boundary
#
# ```text
# UDP RX -> DDR buffer -> ARTERY feedback interface -> feedback waveform -> UDP TX
# ```
#
# The Verilog file in `hw/interface` is a minimal interface-level wrapper. It documents the signal names, valid/ready handshakes, configuration fields, decision outputs, and feedback waveform stream.

# %%
print(Path('../../hw/interface/artery_feedback_interface.v').read_text()[:1200])
