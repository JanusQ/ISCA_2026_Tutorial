# %% [markdown]
# # 4.1 Latency and Feedback Result
#
# This notebook summarizes how the board demo reports feedback latency and visualizes the selected feedback waveform.

# %% [markdown]
# ## GUI Result
#
# ![GUI current result](../results/artery_gui_current.png)

# %%
clock_mhz = 200.0
latency_cycles = 727
latency_us = latency_cycles / (clock_mhz * 1e6) * 1e6
print(f'Latency: {latency_cycles} cycles @ {clock_mhz} MHz = {latency_us:.3f} us')

# %% [markdown]
# ## Measurement Meaning
#
# The latency counter starts when the DDR/readout stream begins feeding the feedback path and stops when the selected feedback waveform becomes valid. The GUI displays both the predicted branch and the latency metadata returned by the hardware test path.
